# %% [markdown]
# # Create LoadData CSVs to use for illumination correction
#
# In this notebook, we create a LoadData CSV that contains paths to each channel per image set for CellProfiler to process.
# We can use this LoadData CSV to run illumination correction (IC) pipeline that saves IC functions in `npy` file format and extract image quality metrics.

# %% [markdown]
# ## Import libraries

# %%
import argparse
import pathlib
import pandas as pd
import re
import os

import sys

sys.path.append("../../utils")
import loaddata_utils as ld_utils
from bandicoot_utils import bandicoot_check

# check if in a jupyter notebook
try:
    cfg = get_ipython().config
    in_notebook = True
except NameError:
    in_notebook = False

# %% [markdown]
# ## Set paths

# %%
argparse = argparse.ArgumentParser(
    description="Create LoadData CSV files to run CellProfiler on the cluster"
)
argparse.add_argument("--HPC", action="store_true", help="Type of compute to run on")

# Parse arguments
args = argparse.parse_args(args=sys.argv[1:] if "ipykernel" not in sys.argv[0] else [])
HPC = args.HPC

print(f"HPC: {HPC}")
# Out:
# HPC: False

# %%
# Set the index directory based on whether HPC is used or not
if HPC:
    # Path for index directory to make loaddata csvs though compute cluster (HPC)
    index_directory = pathlib.Path(
        "/scratch/alpine/jtomkinson@xsede.org/ALSF_screen_data/CHP-134_repo1_screen"
    )
else:
    # Find root directory of the project
    root_dir = pathlib.Path().resolve()

    image_base_dir = bandicoot_check(
        pathlib.Path(os.path.expanduser("~/mnt/bandicoot")).resolve(), root_dir
    )
    # Path for index directory  to make loaddata csv locally
    index_directory = pathlib.Path(
        f"{image_base_dir}/PCCMA_data/CHP-134_repo1_screen/"
    ).resolve(strict=True)

# Paths for parameters to make loaddata csv
config_dir_path = pathlib.Path("./load_data_config").absolute()
output_csv_dir = pathlib.Path("./loaddata_csvs/")
output_csv_dir.mkdir(parents=True, exist_ok=True)

# Recursively find Images folders and print how many plates we are working with
images_folders = []
for current_dir, dirnames, _ in os.walk(index_directory, topdown=True):
    if "Images" in dirnames:
        images_folders.append(pathlib.Path(current_dir) / "Images")
        dirnames.remove("Images")

images_folders = sorted(images_folders)
plate_folders = [images_dir.parent for images_dir in images_folders]
direct_plate_folders = [p for p in plate_folders if p.parent == index_directory]
nested_plate_folders = [p for p in plate_folders if p.parent != index_directory]

print(f"Found {len(images_folders)} Images folders across {len(plate_folders)} plates")
print(f"Direct plate folders under index_directory: {len(direct_plate_folders)}")
print(
    f"Nested plate folders in subdirectories such as reimaged data: {len(nested_plate_folders)}"
)
# Out:
# Found 27 Images folders across 27 plates
# Direct plate folders under index_directory: 24
# Nested plate folders in subdirectories such as reimaged data: 3

# %% [markdown]
# ## Create LoadData CSVs for all data

# %%
# Define the one config path to use
config_path = config_dir_path / "config.yml"

EXPECTED_ROWS = 3456

# Iterate over every discovered plate folder, including nested reimaged-data plates
for subfolder in plate_folders:
    images_dir = subfolder / "Images"

    # Use the exact Index.xml path to avoid scanning a directory full of TIFFs
    xml_file = images_dir / "Index.xml"
    if not xml_file.exists():
        print(f"Skipping {subfolder} (no Index XML found)")
        continue
    print(f"Processing {subfolder} with Index XML: {xml_file.name}")

    # ---- Plate naming logic ----
    base_name = subfolder.name.split("__")[0]

    # Try to extract BR plate ID if present, otherwise use the base name
    match = re.search(r"(BR\d+)", base_name)
    if match:
        plate_name = match.group(1)
        print(f"Using BR plate ID: {plate_name}")
    else:
        plate_name = base_name
        print(f"Using assay plate ID: {plate_name}")

    # ---- Validate PlateID from XML (stream read) ----
    plate_id_in_xml = None
    with open(xml_file, "r") as f:
        for line in f:
            match_xml = re.search(r"<PlateID>(.*?)</PlateID>", line)
            if match_xml:
                plate_id_in_xml = match_xml.group(1)
                break

    if plate_id_in_xml and plate_id_in_xml != plate_name:
        print(
            f"Skipping {subfolder} (PlateID mismatch: {plate_id_in_xml} != {plate_name})"
        )
        continue

    # Create output path with a filename-safe version of the plate name
    path_to_output_csv = (output_csv_dir / f"{plate_name}_loaddata.csv").absolute()

    # Run loaddata creation
    ld_utils.create_loaddata_csv(
        index_directory=images_dir,
        config_path=config_path,
        path_to_output=path_to_output_csv,
    )

    print(f"Created LoadData CSV for {plate_name} at {path_to_output_csv}")

    # ---- Validate CSV row count ----
    try:
        df = pd.read_csv(path_to_output_csv)
        row_count = len(df)

        if row_count != EXPECTED_ROWS:
            print(
                f"WARNING: {plate_name} has {row_count} rows "
                f"(expected {EXPECTED_ROWS})"
            )
        else:
            print(f"{plate_name} row count OK ({row_count})")

    except Exception as e:
        print(f"Error reading CSV for {plate_name}: {e}")
# Out:
# Processing /home/jenna/mnt/bandicoot/PCCMA_data/CHP-134_repo1_screen/BR00149332__2026-01-28T17_43_13-Measurement 1 with Index XML: Index.xml
# Using BR plate ID: BR00149332
# BR00149332_loaddata.csv is created!
# Created LoadData CSV for BR00149332 at /media/18tbdrive/1.Github_Repositories/pccma_repo1_screen_image_profiling/CHP-134_repo1_screen/1.illumination_correction/loaddata_csvs/BR00149332_loaddata.csv
# BR00149332 row count OK (3456)
# Processing /home/jenna/mnt/bandicoot/PCCMA_data/CHP-134_repo1_screen/BR00149333__2026-01-28T19_45_21-Measurement 1 with Index XML: Index.xml
# Using BR plate ID: BR00149333
# BR00149333_loaddata.csv is created!
# Created LoadData CSV for BR00149333 at /media/18tbdrive/1.Github_Repositories/pccma_repo1_screen_image_profiling/CHP-134_repo1_screen/1.illumination_correction/loaddata_csvs/BR00149333_loaddata.csv
# BR00149333 row count OK (3456)
# Processing /home/jenna/mnt/bandicoot/PCCMA_data/CHP-134_repo1_screen/BR00149355__2026-01-29T03_55_30-Measurement 1 with Index XML: Index.xml
# Using BR plate ID: BR00149355
# BR00149355_loaddata.csv is created!
# Created LoadData CSV for BR00149355 at /media/18tbdrive/1.Github_Repositories/pccma_repo1_screen_image_profiling/CHP-134_repo1_screen/1.illumination_correction/loaddata_csvs/BR00149355_loaddata.csv
# BR00149355 row count OK (3456)
# Processing /home/jenna/mnt/bandicoot/PCCMA_data/CHP-134_repo1_screen/BR00149356__2026-01-29T05_58_32-Measurement 1 with Index XML: Index.xml
# Using BR plate ID: BR00149356
# BR00149356_loaddata.csv is created!
# Created LoadData CSV for BR00149356 at /media/18tbdrive/1.Github_Repositories/pccma_repo1_screen_image_profiling/CHP-134_repo1_screen/1.illumination_correction/loaddata_csvs/BR00149356_loaddata.csv
# BR00149356 row count OK (3456)
# Processing /home/jenna/mnt/bandicoot/PCCMA_data/CHP-134_repo1_screen/BR00149357__2026-01-29T08_00_51-Measurement 1 with Index XML: Index.xml
# Using BR plate ID: BR00149357
# BR00149357_loaddata.csv is created!
# Created LoadData CSV for BR00149357 at /media/18tbdrive/1.Github_Repositories/pccma_repo1_screen_image_profiling/CHP-134_repo1_screen/1.illumination_correction/loaddata_csvs/BR00149357_loaddata.csv
# BR00149357 row count OK (3456)
# Processing /home/jenna/mnt/bandicoot/PCCMA_data/CHP-134_repo1_screen/BR00149358__2026-01-29T10_03_42-Measurement 1 with Index XML: Index.xml
# Using BR plate ID: BR00149358
# BR00149358_loaddata.csv is created!
# Created LoadData CSV for BR00149358 at /media/18tbdrive/1.Github_Repositories/pccma_repo1_screen_image_profiling/CHP-134_repo1_screen/1.illumination_correction/loaddata_csvs/BR00149358_loaddata.csv
# BR00149358 row count OK (3456)
# Processing /home/jenna/mnt/bandicoot/PCCMA_data/CHP-134_repo1_screen/BR00149359__2026-01-29T12_06_33-Measurement 1 with Index XML: Index.xml
# Using BR plate ID: BR00149359
# BR00149359_loaddata.csv is created!
# Created LoadData CSV for BR00149359 at /media/18tbdrive/1.Github_Repositories/pccma_repo1_screen_image_profiling/CHP-134_repo1_screen/1.illumination_correction/loaddata_csvs/BR00149359_loaddata.csv
# BR00149359 row count OK (3456)
# Processing /home/jenna/mnt/bandicoot/PCCMA_data/CHP-134_repo1_screen/BR00149360__2026-01-29T14_09_13-Measurement 1 with Index XML: Index.xml
# Using BR plate ID: BR00149360
# BR00149360_loaddata.csv is created!
# Created LoadData CSV for BR00149360 at /media/18tbdrive/1.Github_Repositories/pccma_repo1_screen_image_profiling/CHP-134_repo1_screen/1.illumination_correction/loaddata_csvs/BR00149360_loaddata.csv
# BR00149360 row count OK (3456)
# Processing /home/jenna/mnt/bandicoot/PCCMA_data/CHP-134_repo1_screen/BR00149361__2026-01-29T16_12_00-Measurement 1 with Index XML: Index.xml
# Using BR plate ID: BR00149361
# BR00149361_loaddata.csv is created!
# Created LoadData CSV for BR00149361 at /media/18tbdrive/1.Github_Repositories/pccma_repo1_screen_image_profiling/CHP-134_repo1_screen/1.illumination_correction/loaddata_csvs/BR00149361_loaddata.csv
# BR00149361 row count OK (3456)
# Processing /home/jenna/mnt/bandicoot/PCCMA_data/CHP-134_repo1_screen/BR00149543__2026-02-09T18_07_44-Measurement 1 with Index XML: Index.xml
# Using BR plate ID: BR00149543
# BR00149543_loaddata.csv is created!
# Created LoadData CSV for BR00149543 at /media/18tbdrive/1.Github_Repositories/pccma_repo1_screen_image_profiling/CHP-134_repo1_screen/1.illumination_correction/loaddata_csvs/BR00149543_loaddata.csv
# WARNING: BR00149543 has 3455 rows (expected 3456)
# Processing /home/jenna/mnt/bandicoot/PCCMA_data/CHP-134_repo1_screen/BR00149544__2026-02-09T20_10_07-Measurement 1 with Index XML: Index.xml
# Using BR plate ID: BR00149544
# BR00149544_loaddata.csv is created!
# Created LoadData CSV for BR00149544 at /media/18tbdrive/1.Github_Repositories/pccma_repo1_screen_image_profiling/CHP-134_repo1_screen/1.illumination_correction/loaddata_csvs/BR00149544_loaddata.csv
# BR00149544 row count OK (3456)
# Processing /home/jenna/mnt/bandicoot/PCCMA_data/CHP-134_repo1_screen/BR00149545__2026-02-09T22_12_53-Measurement 1 with Index XML: Index.xml
# Using BR plate ID: BR00149545
# BR00149545_loaddata.csv is created!
# Created LoadData CSV for BR00149545 at /media/18tbdrive/1.Github_Repositories/pccma_repo1_screen_image_profiling/CHP-134_repo1_screen/1.illumination_correction/loaddata_csvs/BR00149545_loaddata.csv
# BR00149545 row count OK (3456)
# Processing /home/jenna/mnt/bandicoot/PCCMA_data/CHP-134_repo1_screen/BR00149546__2026-02-10T00_15_06-Measurement 1 with Index XML: Index.xml
# Using BR plate ID: BR00149546
# BR00149546_loaddata.csv is created!
# Created LoadData CSV for BR00149546 at /media/18tbdrive/1.Github_Repositories/pccma_repo1_screen_image_profiling/CHP-134_repo1_screen/1.illumination_correction/loaddata_csvs/BR00149546_loaddata.csv
# BR00149546 row count OK (3456)
# Processing /home/jenna/mnt/bandicoot/PCCMA_data/CHP-134_repo1_screen/BR00149547__2026-02-10T02_17_43-Measurement 1 with Index XML: Index.xml
# Using BR plate ID: BR00149547
# BR00149547_loaddata.csv is created!
# Created LoadData CSV for BR00149547 at /media/18tbdrive/1.Github_Repositories/pccma_repo1_screen_image_profiling/CHP-134_repo1_screen/1.illumination_correction/loaddata_csvs/BR00149547_loaddata.csv
# WARNING: BR00149547 has 3455 rows (expected 3456)
# Processing /home/jenna/mnt/bandicoot/PCCMA_data/CHP-134_repo1_screen/BR00149548__2026-02-10T04_20_08-Measurement 1 with Index XML: Index.xml
# Using BR plate ID: BR00149548
# BR00149548_loaddata.csv is created!
# Created LoadData CSV for BR00149548 at /media/18tbdrive/1.Github_Repositories/pccma_repo1_screen_image_profiling/CHP-134_repo1_screen/1.illumination_correction/loaddata_csvs/BR00149548_loaddata.csv
# BR00149548 row count OK (3456)
# Processing /home/jenna/mnt/bandicoot/PCCMA_data/CHP-134_repo1_screen/BR00149549__2026-02-10T06_22_42-Measurement 1 with Index XML: Index.xml
# Using BR plate ID: BR00149549
# BR00149549_loaddata.csv is created!
# Created LoadData CSV for BR00149549 at /media/18tbdrive/1.Github_Repositories/pccma_repo1_screen_image_profiling/CHP-134_repo1_screen/1.illumination_correction/loaddata_csvs/BR00149549_loaddata.csv
# BR00149549 row count OK (3456)
# Processing /home/jenna/mnt/bandicoot/PCCMA_data/CHP-134_repo1_screen/BR00149550__2026-02-10T08_25_27-Measurement 1 with Index XML: Index.xml
# Using BR plate ID: BR00149550
# BR00149550_loaddata.csv is created!
# Created LoadData CSV for BR00149550 at /media/18tbdrive/1.Github_Repositories/pccma_repo1_screen_image_profiling/CHP-134_repo1_screen/1.illumination_correction/loaddata_csvs/BR00149550_loaddata.csv
# WARNING: BR00149550 has 3446 rows (expected 3456)
# Processing /home/jenna/mnt/bandicoot/PCCMA_data/CHP-134_repo1_screen/BR00149551__2026-02-11T18_50_11-Measurement 2 with Index XML: Index.xml
# Using BR plate ID: BR00149551
# BR00149551_loaddata.csv is created!
# Created LoadData CSV for BR00149551 at /media/18tbdrive/1.Github_Repositories/pccma_repo1_screen_image_profiling/CHP-134_repo1_screen/1.illumination_correction/loaddata_csvs/BR00149551_loaddata.csv
# BR00149551 row count OK (3456)
# Processing /home/jenna/mnt/bandicoot/PCCMA_data/CHP-134_repo1_screen/BR00149555__2026-02-10T23_06_54-Measurement 1 with Index XML: Index.xml
# Using BR plate ID: BR00149555
# BR00149555_loaddata.csv is created!
# Created LoadData CSV for BR00149555 at /media/18tbdrive/1.Github_Repositories/pccma_repo1_screen_image_profiling/CHP-134_repo1_screen/1.illumination_correction/loaddata_csvs/BR00149555_loaddata.csv
# BR00149555 row count OK (3456)
# Processing /home/jenna/mnt/bandicoot/PCCMA_data/CHP-134_repo1_screen/BR00149556__2026-02-11T20_52_45-Measurement 2 with Index XML: Index.xml
# Using BR plate ID: BR00149556
# BR00149556_loaddata.csv is created!
# Created LoadData CSV for BR00149556 at /media/18tbdrive/1.Github_Repositories/pccma_repo1_screen_image_profiling/CHP-134_repo1_screen/1.illumination_correction/loaddata_csvs/BR00149556_loaddata.csv
# BR00149556 row count OK (3456)
# Processing /home/jenna/mnt/bandicoot/PCCMA_data/CHP-134_repo1_screen/BR00149557__2026-02-11T22_55_15-Measurement 2 with Index XML: Index.xml
# Using BR plate ID: BR00149557
# BR00149557_loaddata.csv is created!
# Created LoadData CSV for BR00149557 at /media/18tbdrive/1.Github_Repositories/pccma_repo1_screen_image_profiling/CHP-134_repo1_screen/1.illumination_correction/loaddata_csvs/BR00149557_loaddata.csv
# BR00149557 row count OK (3456)
# Processing /home/jenna/mnt/bandicoot/PCCMA_data/CHP-134_repo1_screen/BR00149558__2026-02-12T00_57_50-Measurement 2 with Index XML: Index.xml
# Using BR plate ID: BR00149558
# BR00149558_loaddata.csv is created!
# Created LoadData CSV for BR00149558 at /media/18tbdrive/1.Github_Repositories/pccma_repo1_screen_image_profiling/CHP-134_repo1_screen/1.illumination_correction/loaddata_csvs/BR00149558_loaddata.csv
# BR00149558 row count OK (3456)
# Processing /home/jenna/mnt/bandicoot/PCCMA_data/CHP-134_repo1_screen/BR00149559__2026-02-12T03_00_16-Measurement 2 with Index XML: Index.xml
# Using BR plate ID: BR00149559
# BR00149559_loaddata.csv is created!
# Created LoadData CSV for BR00149559 at /media/18tbdrive/1.Github_Repositories/pccma_repo1_screen_image_profiling/CHP-134_repo1_screen/1.illumination_correction/loaddata_csvs/BR00149559_loaddata.csv
# BR00149559 row count OK (3456)
# Processing /home/jenna/mnt/bandicoot/PCCMA_data/CHP-134_repo1_screen/BR00149561__2026-02-12T05_02_47-Measurement 2 with Index XML: Index.xml
# Using BR plate ID: BR00149561
# BR00149561_loaddata.csv is created!
# Created LoadData CSV for BR00149561 at /media/18tbdrive/1.Github_Repositories/pccma_repo1_screen_image_profiling/CHP-134_repo1_screen/1.illumination_correction/loaddata_csvs/BR00149561_loaddata.csv
# BR00149561 row count OK (3456)
# Processing /home/jenna/mnt/bandicoot/PCCMA_data/CHP-134_repo1_screen/CHP-134 re-upload/Assay Plate_1_3__2026-01-28T21_47_55-Measurement 14 with Index XML: Index.xml
# Using assay plate ID: Assay Plate_1_3
# Assay Plate_1_3_loaddata.csv is created!
# Created LoadData CSV for Assay Plate_1_3 at /media/18tbdrive/1.Github_Repositories/pccma_repo1_screen_image_profiling/CHP-134_repo1_screen/1.illumination_correction/loaddata_csvs/Assay Plate_1_3_loaddata.csv
# Assay Plate_1_3 row count OK (3456)
# Processing /home/jenna/mnt/bandicoot/PCCMA_data/CHP-134_repo1_screen/CHP-134 re-upload/Assay Plate_1_4__2026-01-28T23_50_06-Measurement 11 with Index XML: Index.xml
# Using assay plate ID: Assay Plate_1_4
# Assay Plate_1_4_loaddata.csv is created!
# Created LoadData CSV for Assay Plate_1_4 at /media/18tbdrive/1.Github_Repositories/pccma_repo1_screen_image_profiling/CHP-134_repo1_screen/1.illumination_correction/loaddata_csvs/Assay Plate_1_4_loaddata.csv
# Assay Plate_1_4 row count OK (3456)
# Processing /home/jenna/mnt/bandicoot/PCCMA_data/CHP-134_repo1_screen/CHP-134 re-upload/Assay Plate_1_5__2026-01-29T01_52_49-Measurement 6 with Index XML: Index.xml
# Using assay plate ID: Assay Plate_1_5
# Assay Plate_1_5_loaddata.csv is created!
# Created LoadData CSV for Assay Plate_1_5 at /media/18tbdrive/1.Github_Repositories/pccma_repo1_screen_image_profiling/CHP-134_repo1_screen/1.illumination_correction/loaddata_csvs/Assay Plate_1_5_loaddata.csv
# Assay Plate_1_5 row count OK (3456)
